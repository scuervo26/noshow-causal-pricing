# %% [markdown]
# # Notebook 07 — Webscraping de Mercado (parámetros para Monte Carlo)
#
# Recoge precios de competidores de automatización SaaS, listas de precios de cadenas clínicas (dental / fisio / psicología) y costes de comunicación SMS/WhatsApp. Alimenta los rangos paramétricos del Notebook 06 y la sección de mercado del TFG escrito.
#
# Cumple el requisito de la Guía Docente de aplicar una **técnica no convencional para la obtención de datos** (webscraping).
#
# Ver `PLAN_TECNICO.md` → Notebook 07 para targets, framing metodológico y la nota de triangulación de fuentes.
